# %%
# Hangman game
#

# -----------------------------------
# Helper code
# You don't need to understand this helper code,
# but you will have to know how to use the functions
# (so be sure to read the docstrings!)

import random

WORDLIST_FILENAME = "words.txt"

def loadWords():
    """
    Returns a list of valid words. Words are strings of lowercase letters.
    
    Depending on the size of the word list, this function may
    take a while to finish.
    """
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist

def chooseWord(wordlist):
    """
    wordlist (list): list of words (strings)

    Returns a word from wordlist at random
    """
    return random.choice(wordlist)

# end of helper code
# -----------------------------------

# Load the list of words into the variable wordlist
# so that it can be accessed from anywhere in the program
wordlist = loadWords()

def isWordGuessed(secretWord, lettersGuessed):
    '''
    secretWord: string, the word the user is guessing
    lettersGuessed: list, what letters have been guessed so far
    returns: boolean, True if all the letters of secretWord are in lettersGuessed;
      False otherwise
    '''
    correctGuesses = 0
    for guessed in lettersGuessed:
        if (guessed in secretWord):
            correctGuesses += (secretWord.count(guessed) / lettersGuessed.count(guessed))
        if (correctGuesses == len(secretWord)):
            return True
        else:
            return False



def getGuessedWord(secretWord, lettersGuessed):
    '''
    secretWord: string, the word the user is guessing
    lettersGuessed: list, what letters have been guessed so far
    returns: string, comprised of letters and underscores that represents
      what letters in secretWord have been guessed so far.
    '''
    guessed = ''
    for letter in secretWord:
        if (letter in lettersGuessed):
            guessed += ' ' + letter + ' '
        else:
            guessed += ' _ '
        return guessed



def getAvailableLetters(lettersGuessed):
    '''
    lettersGuessed: list, what letters have been guessed so far
    returns: string, comprised of letters that represents what letters have not
      yet been guessed.
    '''
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    available = ' '
    for letter in alphabet:
        if not(letter in lettersGuessed):
            available += letter
        return available
    

def hangman(secretWord):
    '''
    secretWord: string, the secret word to guess.

    Starts up an interactive game of Hangman.

    * At the start of the game, let the user know how many 
      letters the secretWord contains.

    * Ask the user to supply one guess (i.e. letter) per round.

    * The user should receive feedback immediately after each guess 
      about whether their guess appears in the computers word.

    * After each round, you should also display to the user the 
      partially guessed word so far, as well as letters that the 
      user has not yet guessed.

    Follows the other limitations detailed in the problem write-up.
    '''
    print('Welcome to Hangman, hooman!')
    print('Your word is ' + str(len(secretWord)) + ' letters long. GOOD LUCK HOOMAN!')
    print('--------------------------')
    availableGuesses = 10
    lost = False
    guessList = []
    while (availableGuesses > 0 and lost == False):
        print('You have ' + str(availableGuesses) + ' guesses left. NO PRESSURE HOOMAN!')
        print('Available letters:', getAvailableLetters(guessList))
        guess = input('Please guess a letter HOOMAN: ').lower()
        if (guess in secretWord and not(guess in guessList)):
            print('oop. compooter dummy. hooman got this one:', getGuessedWord(secretWord, guessList + [guess]))
            print('-------------------')
        elif (guess in guessList):
            print('THAT TICKLES ME HOOMAN! YOU HAVE ALREADY GUESSED THAT LETTER, SILLY HOOMAN!:', getGuessedWord(secretWord, guessList))
            print('-------------------')
        elif not(guess in secretWord):
            print('STOOPID HOOMAN, THAT LETTER IS NOT IN THE WORD:', getGuessedWord, guessList)
            print('-------------------')
            availableGuesses -= 1
            
        guessList.append(guess)
        
        if (isWordGuessed(secretWord, guessList)):
            print('Conglaturations HOOMAN! YOU ARE AN WINNER!')
            break
        if (availableGuesses <= 0):
            lost = True
            print('STOOPID HOOMAN, YOU NO GOOD AT HANGMAN! ROBOTS WIN!')
            print('THE WORD YOU COULDNT GUESS WAS ', secretWord)
            break






# When you've completed your hangman function, uncomment these two lines
# and run this file to test! (hint: you might want to pick your own
# secretWord while you're testing)

secretWord = chooseWord(wordlist).lower()
hangman(secretWord)
# Out:
# Loading word list from file...
#    55909 words loaded.
# Welcome to Hangman, hooman!
# Your word is 8 letters long. GOOD LUCK HOOMAN!
# --------------------------
# You have 10 guesses left. NO PRESSURE HOOMAN!
# Available letters:  a
# Please guess a letter HOOMAN: a
# oop. compooter dummy. hooman got this one:  _
# -------------------
# You have 10 guesses left. NO PRESSURE HOOMAN!
# Available letters:
# Please guess a letter HOOMAN: e
# STOOPID HOOMAN, THAT LETTER IS NOT IN THE WORD: <function getGuessedWord at 0x0000026E87A21A60> ['a']
# -------------------
# You have 9 guesses left. NO PRESSURE HOOMAN!
# Available letters:
# Please guess a letter HOOMAN: e
# THAT TICKLES ME HOOMAN! YOU HAVE ALREADY GUESSED THAT LETTER, SILLY HOOMAN!:  _
# -------------------
# You have 9 guesses left. NO PRESSURE HOOMAN!
# Available letters:
# Please guess a letter HOOMAN: i
# oop. compooter dummy. hooman got this one:  _
# -------------------
# You have 9 guesses left. NO PRESSURE HOOMAN!
# ...
